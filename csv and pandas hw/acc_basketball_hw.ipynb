# %% [markdown]
# <a href="https://colab.research.google.com/github/xcz8pd/xcz8pd/blob/main/csv%20and%20pandas%20hw/acc_basketball_hw.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

acc_stats_df = pd.read_csv('acc_players-2324F.csv', header=1)
print("Total 2023-2024 ACC Stats")
acc_stats_df.head(5)
# Out:
# Total 2023-2024 ACC Stats
#    Rk         Player Class Pos          School   G   MP  TRB  AST  STL  ...  \
# 0   1   Amaree Abram    SO   G    Georgia Tech  10  108   17   11    1  ...
# 1   2   Sola Adebisi    FR   F   Florida State   7    9    1    1    0  ...
# 2   3  Prince Aligbe    SO   F  Boston College  35  651  119   21   15  ...
# 3   4     Abe Atiyeh    SR   G  Boston College   4    6    0    0    0  ...
# 4   5    Zack Austin    JR   F      Pittsburgh  33  746  137   29   32  ...
#
#    TOV  PF  PTS    FG%    2P%    3P%    FT%   PER   WS  BPM
# 0    9  10   34  0.262  0.318  0.200  0.615   4.1 -0.1 -6.4
# 1    1   1    2  0.500  0.500    NaN    NaN   3.5  0.0 -6.7
# 2   30  51  164  0.435  0.522  0.147  0.620   9.4  0.9 -1.3
# 3    1   0    3  0.333  0.000  1.000    NaN   1.1  0.0 -8.2
# 4   13  35  216  0.417  0.563  0.295  0.737  18.0  2.9  7.9
#
# [5 rows x 21 columns]

# %%
total_points = acc_stats_df['PTS'].sum()
print("Total points scored:")
total_points
# Out:
# Total points scored:
# 38411

# %%
most_minutes = acc_stats_df[['Player','MP']].sort_values(by='MP', ascending=False)
print("Player with most minutes:")
most_minutes.head(1)
# Out:
# Player with most minutes:
#             Player    MP
# 135  Casey Morsell  1333

# %%
top_5_trb = acc_stats_df[['Player', 'TRB']].sort_values(by='TRB', ascending=False).head(5)
print("Top 5 players with most rebounds:")
top_5_trb
# Out:
# Top 5 players with most rebounds:
#               Player  TRB
# 5      Armando Bacot  380
# 178  Ian Schieffelin  340
# 90   Harrison Ingram  327
# 44    Mohamed Diarra  311
# 149    Norchad Omier  309

# %%
over_500_minutes = acc_stats_df[acc_stats_df['MP'] > 500]
print("Players with more than 500 minutes:")
over_500_minutes
# Out:
# Players with more than 500 minutes:
#       Rk            Player Class Pos          School   G    MP  TRB  AST  STL  \
# 2      3     Prince Aligbe    SO   F  Boston College  35   651  119   21   15
# 4      5       Zack Austin    JR   F      Pittsburgh  33   746  137   29   32
# 5      6     Armando Bacot    SR   F  North Carolina  37  1123  380   56   22
# 7      8     Reece Beekman    SR   G        Virginia  34  1114  124  212   68
# 9     10        Chris Bell    SO   F        Syracuse  32   865   75   21   18
# ..   ...               ...   ...  ..             ...  ..   ...  ...  ...  ...
# 203  204     Jamir Watkins    JR   F   Florida State  33   928  199   91   64
# 206  207         Tre White    SO   G      Louisville  29   907  170   39   24
# 207  208  Chauncey Wiggins    SO   F         Clemson  36   639   76   33    6
# 209  210   Curtis Williams    FR   G      Louisville  32   564   42   20   12
# ...

# %%
highest_ast = over_500_minutes[['Player','AST']].sort_values(by='AST', ascending=False)
print("Player with most assists:")
highest_ast.head(1)
# Out:
# Player with most assists:
#           Player  AST
# 7  Reece Beekman  212

# %%
top_3_assist = acc_stats_df[['Player', 'AST']].sort_values(by='AST', ascending=False).head(3)
print("Top 3 players with most assists:")
top_3_assist
# Out:
# Top 3 players with most assists:
#              Player  AST
# 7     Reece Beekman  212
# 215  Jaeden Zackery  152
# 21    Elliot Cadeau  150

# %%
top_3_shot_blockers = acc_stats_df[['Player', 'BLK']].sort_values(by='BLK', ascending=False).head(3)
print("Top 3 players with most blocks:")
top_3_shot_blockers
# Out:
# Top 3 players with most blocks:
#             Player  BLK
# 51       Ryan Dunn   77
# 157   Quinten Post   61
# 5    Armando Bacot   56

# %%
total_points_per_school = acc_stats_df.groupby('School')[['PTS']].sum()
print("Total points scored per school:")
total_points_per_school
# Out:
# Total points scored per school:
#                  PTS
# School
# Boston College  2667
# Clemson         2785
# Duke            2830
# Florida State   2526
# Georgia Tech    2272
# Louisville      2304
# Miami (FL)      2424
# NC State        3101
# North Carolina  3032
# Notre Dame      2113
# Pittsburgh      2495
# Syracuse        2442
# Virginia        2140
# Virginia Tech   2547
# Wake Forest     2733

# %%
total_assists_per_school = acc_stats_df.groupby('School')[['AST']].sum()
print("Total assists per school:")
total_assists_per_school
# Out:
# Total assists per school:
#                 AST
# School
# Boston College  509
# Clemson         533
# Duke            551
# Florida State   406
# Georgia Tech    425
# Louisville      356
# Miami (FL)      454
# NC State        536
# North Carolina  536
# Notre Dame      335
# Pittsburgh      452
# Syracuse        442
# Virginia        509
# Virginia Tech   514
# Wake Forest     429

# %%
total_points_per_school.sort_values(by='PTS', ascending=False).head(3)
# Out:
#                  PTS
# School
# NC State        3101
# North Carolina  3032
# Duke            2830

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

top_5_scorers = acc_stats_df[['Player', 'PTS']].sort_values(by='PTS', ascending=False).head(5)

plt.figure(figsize=(10,6))
sns.barplot(x='PTS', y='Player', data=top_5_scorers)
plt.xlabel('Points')
plt.ylabel('Player')
plt.title('Top 5 2023-2024 Season Scorers')
plt.show()

# %%
plt.scatter(acc_stats_df['FG%'], acc_stats_df['WS'], color='blue')
plt.xlabel('Field Goal %')
plt.ylabel('Win Shares')
plt.title('Scatter Plot of Field Goal % vs. Win Shares')
plt.show()

correlation = acc_stats_df['FG%'].corr(acc_stats_df['WS'])
print(f"Correlation coefficient: {correlation}")
# Out:
# Correlation coefficient: 0.4210663894199787
